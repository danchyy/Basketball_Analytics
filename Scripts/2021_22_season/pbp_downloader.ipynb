# %%
import requests
import pandas as pd
import tqdm
import bs4
import json
import matplotlib.pyplot as plt
from adjustText import adjust_text
from pathlib import Path
import time

# %%
from nba_api.stats.endpoints.playbyplayv2 import PlayByPlayV2

# %%
from nba_api.stats.endpoints.playbyplay import PlayByPlay
from nba_api.stats.endpoints.leaguegamefinder import LeagueGameFinder
from nba_api.stats.static.players import find_players_by_full_name
from nba_api.stats.static.teams import find_teams_by_full_name
from nba_api.stats.endpoints.playergamelogs import PlayerGameLogs

# %%
path = Path('pbp_data/2021-22.csv')
data_frame = None
if path.exists():
    data_frame = pd.read_csv(str(path))
    data_frame.loc[:, 'GAME_ID'] = [f"00{item}" for item in data_frame.GAME_ID.astype(str)]

# %% [markdown]
# ## Downloading cur Season

# %%
season = '2021-22'
print(f"Processing {season}")
pbp_dfs = []
game_finder = LeagueGameFinder(season_nullable=season, league_id_nullable='00', season_type_nullable='Regular Season')
df = game_finder.get_data_frames()[0]
game_ids = df.GAME_ID.unique()
for game_id in tqdm.tqdm(game_ids):
    if data_frame is not None and game_id in data_frame.GAME_ID.tolist():
        continue
    while True:
        try:
            pbp_df = PlayByPlayV2(game_id=game_id).get_data_frames()[0]
            break
        except Exception as e:
            print(f"Error occured: {e}, Game ID: {game_id}, retrying")
            time.sleep(0.1)
    pbp_dfs.append(pbp_df)
    time.sleep(0.25)
full_df = pd.concat([data_frame] + pbp_dfs)
# Out:
# Processing 2021-22
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 608/608 [00:39<00:00, 15.21it/s]
# c:\users\danie\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
full_df.loc[:, "PCTIMESECONDS"] = [720 - (int(item.split(":")[0]) * 60 + int(item.split(":")[1])) for item in full_df.PCTIMESTRING.tolist()]

full_df = full_df.fillna({
    "HOMEDESCRIPTION": "",
    "NEUTRALDESCRIPTION": "",
    "VISITORDESCRIPTION": ""
})

# %%
full_df.to_csv('pbp_data/2021-22.csv', index=False)

# %%
full_df = pd.read_csv('pbp_data/2021-22.csv')

full_df = full_df.fillna({
    "HOMEDESCRIPTION": "",
    "NEUTRALDESCRIPTION": "",
    "VISITORDESCRIPTION": ""
})
full_df.loc[:, 'GAME_ID'] = [f"00{item}" for item in full_df.GAME_ID.astype(str)]

# %% [markdown]
# ## Finding first shot of each game

# %%
game_ids = full_df.GAME_ID.unique()

# %%
first_shots = []
first_makes = []

for game_id in game_ids:
    cur_game = full_df.loc[full_df.GAME_ID == game_id]    
    first_shots.append(cur_game.loc[(cur_game.EVENTMSGTYPE == 2) | (cur_game.EVENTMSGTYPE == 1)].iloc[0])
    first_makes.append(cur_game.loc[(cur_game.EVENTMSGTYPE == 1)].iloc[0])

# %%
first_df = pd.DataFrame(first_shots)
first_makes_df = pd.DataFrame(first_makes)

# %%
first_df.to_csv('first_shots.csv')

# %%
first_makes_df.to_csv('first_makes.csv')

# %% [markdown]
# first_nba_shots

# %%
cur_game.loc[(cur_game.EVENTMSGTYPE == 2) | (cur_game.EVENTMSGTYPE == 1)]
# Out:
# EVENTMSGACTIONTYPE                                       6
# EVENTMSGTYPE                                             2
# EVENTNUM                                                 7
# GAME_ID                                         0022100239
# HOMEDESCRIPTION              MISS Barrett 2' Driving Layup
# NEUTRALDESCRIPTION
# PCTIMESECONDS                                           17
# PCTIMESTRING                                         11:43
# PERIOD                                                   1
# PERSON1TYPE                                              4
# PERSON2TYPE                                              0
# PERSON3TYPE                                              0
# PLAYER1_ID                                         1629628
# PLAYER1_NAME                                    RJ Barrett
# PLAYER1_TEAM_ABBREVIATION                              NYK
# PLAYER1_TEAM_CITY                                 New York
# PLAYER1_TEAM_ID                                1.61061e+09
# PLAYER1_TEAM_NICKNAME                               Knicks
# PLAYER2_ID                                               0
# PLAYER2_NAME                                           NaN
# PLAYER2_TEAM_ABBREVIATION                              NaN
# PLAYER2_TEAM_CITY                                      NaN
# PLAYER2_TEAM_ID                                        NaN
# PLAYER2_TEAM_NICKNAME                                  NaN
# PLAYER3_ID                                               0
# PLAYER3_NAME                                           NaN
# PLAYER3_TEAM_ABBREVIATION                              NaN
# PLAYER3_TEAM_CITY                                      NaN
# PLAYER3_TEAM_ID                                        NaN
# PLAYER3_TEAM_NICKNAME                                  NaN
# SCORE                                                  NaN
# SCOREMARGIN                                            NaN
# VIDEO_AVAILABLE_FLAG                                     1
# VISITORDESCRIPTION
# WCTIMESTRING                                       5:13 PM
# Name: 2, dtype: object

# %%
df = game_finder.get_data_frames()[0]

# %%
for i in range(len(df)):
    print(f"{df.iloc[i].GAME_ID}, {df.iloc[i].MATCHUP}")
# Out:
# 0022100305, PHI vs. ORL
# 0022100305, ORL @ PHI
# 0022100306, MIA vs. DEN
# 0022100306, DEN @ MIA
# 0022100308, HOU vs. OKC
# 0022100308, OKC @ HOU
# 0022100307, CHI vs. CHA
# 0022100307, CHA @ CHI
# 0022100309, MIN vs. IND
# 0022100309, IND @ MIN
# 0022100310, CLE @ DAL
# 0022100310, DAL vs. CLE
# 0022100311, WAS @ SAS
# 0022100311, SAS vs. WAS
# 0022100312, UTA vs. POR
# 0022100312, POR @ UTA
# 0022100313, LAC vs. NOP
# 0022100313, NOP @ LAC
# 0022100304, DET @ LAL
# 0022100301, MIL @ IND
# 0022100304, LAL vs. DET
# 0022100300, GSW @ LAC
# 0022100300, LAC vs. GSW
# 0022100301, IND vs. MIL
# 0022100303, MEM vs. SAC
# 0022100303, SAC @ MEM
# 0022100302, BOS @ TOR
# 0022100302, TOR vs. BOS
# 0022100292, PHI vs. MIN
# 0022100292, MIN @ PHI
# 0022100293, NYK @ ATL
# 0022100293, ATL vs. NYK
# 0022100299, NOP @ UTA
# 0022100299, UTA vs. NOP
# 0022100297, CHA @ HOU
# 0022100297, HOU vs. CHA
# 0022100298, DAL vs. WAS
# 0022100298, WAS @ DAL
# 0022100296, CHI vs. MIA
# 0022100296, MIA @ CHI
# 0022100295, CLE vs. ORL
# 0022100295, ORL @ CLE
# 0022100294, BKN vs. PHX
# 0022100294, PHX @ BKN
# 0022100281, MIN @ CHA
# 0022100281, CHA vs. MIN
# 0022100282, PHX @ NYK
# 0022100280, LAC vs. DET
# 0022100280, DET @ LAC
# 0022100282, NYK vs. PHX
# 0022100283, CHI @ ORL
# 0022100283, ORL vs. CHI
# 0022100288, MIL @ DEN
# 0022100287, BOS @ SAS
# 0022100287, SAS vs. BOS
# 0022100288, DEN vs. MIL
# 0022100289, UTA vs. NOP
# 0022100289, NOP @ UTA
# 0022100290, POR @ GSW
# 0022100290, GSW vs. POR
# 0022100291, LAL vs. SAC
# 0022100291, SAC @ LAL
# 0022100286, WAS @ OKC
# 0022100286, OKC vs. WAS
# 0022100284, TOR @ IND
# 0022100284, IND vs. TOR
# 0022100285, ATL @ MEM
# 0022100285, MEM vs. ATL
# 0022100276, OKC vs. UTA
# 0022100276, UTA @ OKC
# 0022100272, MEM vs. TOR
# 0022100267, PHX @ CLE
# 0022100267, CLE vs. PHX
# 0022100269, CHA @ ORL
# 0022100268, LAL @ IND
# 0022100268, IND vs. LAL
# 0022100269, ORL vs. CHA
# 0022100273, DET @ MIL
# 0022100270, BKN @ BOS
# 0022100270, BOS vs. BKN
# 0022100273, MIL vs. DET
# 0022100275, NOP vs. WAS
# 0022100275, WAS @ NOP
# 0022100277, ATL @ SAS
# 0022100277, SAS vs. ATL
# 0022100274, MIA @ MIN
# 0022100271, CHI @ HOU
# 0022100271, HOU vs. CHI
# 0022100274, MIN vs. MIA
# 0022100279, SAC vs. POR
# 0022100279, POR @ SAC
# 0022100278, PHI @ GSW
# 0022100278, GSW vs. PHI
# 0022100272, TOR @ MEM
# 0022100266, DAL @ LAC
# 0022100266, LAC vs. DAL
# 0022100265, DEN @ POR
# 0022100265, POR vs. DEN
# 0022100264, NYK vs. LAL
# 0022100264, LAL @ NYK
# 0022100263, DET vs. MIA
# 0022100263, MIA @ DET
# 0022100253, BKN @ CLE
# 0022100258, ORL @ MIL
# 0022100258, MIL vs. ORL
# 0022100253, CLE vs. BKN
# 0022100262, PHI @ SAC
# 0022100257, CHI vs. IND
# 0022100257, IND @ CHI
# 0022100262, SAC vs. PHI
# 0022100261, MEM @ UTA
# 0022100261, UTA vs. MEM
# 0022100259, NOP vs. MIN
# 0022100259, MIN @ NOP
# 0022100256, HOU @ BOS
# 0022100256, BOS vs. HOU
# 0022100260, SAS vs. PHX
# 0022100254, WAS vs. CHA
# 0022100254, CHA @ WAS
# 0022100255, OKC @ ATL
# 0022100255, ATL vs. OKC
# 0022100260, PHX @ SAS
# 0022100249, DET vs. LAL
# 0022100249, LAL @ DET
# 0022100252, TOR @ GSW
# 0022100252, GSW vs. TOR
# 0022100250, CHI vs. NYK
# 0022100250, NYK @ CHI
# 0022100251, DEN @ PHX
# 0022100251, PHX vs. DEN
# 0022100248, DAL @ LAC
# 0022100248, LAC vs. DAL
# 0022100242, CHA @ ATL
# 0022100244, MIL vs. ORL
# 0022100244, ORL @ MIL
# 0022100245, MIN vs. MEM
# 0022100245, MEM @ MIN
# 0022100246, PHI @ POR
# 0022100246, POR vs. PHI
# 0022100247, UTA @ SAC
# 0022100247, SAC vs. UTA
# 0022100239, NYK vs. HOU
# 0022100239, HOU @ NYK
# 0022100242, ATL vs. CHA
# 0022100243, BOS vs. OKC
# 0022100243, OKC @ BOS
# 0022100240, NOP @ IND
# 0022100240, IND vs. NOP
# 0022100241, MIA @ WAS
# 0022100241, WAS vs. MIA
# 0022100238, SAC vs. TOR
# 0022100238, TOR @ SAC
# 0022100234, MIL vs. OKC
# 0022100234, OKC @ MIL
# 0022100237, DAL @ PHX
# 0022100237, PHX vs. DAL
# 0022100235, NOP vs. LAC
# 0022100235, LAC @ NOP
# 0022100236, CHI @ DEN
# 0022100236, DEN vs. CHI
# 0022100232, BOS vs. LAL
# 0022100232, LAL @ BOS
# 0022100233, ORL @ BKN
# 0022100233, BKN vs. ORL
# 0022100230, IND @ CHA
# 0022100230, CHA vs. IND
# 0022100231, GSW @ DET
# 0022100231, DET vs. GSW
# 0022100225, WAS @ MIA
# 0022100225, MIA vs. WAS
# 0022100224, CLE vs. GSW
# 0022100224, GSW @ CLE
# 0022100226, LAC @ MEM
# 0022100226, MEM vs. LAC
# 0022100227, SAS @ MIN
# 0022100227, MIN vs. SAS
# 0022100229, UTA vs. TOR
# 0022100229, TOR @ UTA
# 0022100228, DEN vs. PHI
# 0022100228, PHI @ DEN
# 0022100213, WAS @ CHA
# 0022100213, CHA vs. WAS
# 0022100214, IND @ DET
# 0022100218, ORL @ NYK
# 0022100218, NYK vs. ORL
# 0022100223, CHI @ POR
# 0022100223, POR vs. CHI
# 0022100222, DAL @ PHX
# 0022100222, PHX vs. DAL
# 0022100220, MIN vs. SAC
# 0022100220, SAC @ MIN
# 0022100221, HOU @ OKC
# 0022100221, OKC vs. HOU
# 0022100219, MIL vs. LAL
# 0022100219, LAL @ MIL
# 0022100217, NOP @ MIA
# 0022100217, MIA vs. NOP
# 0022100216, CLE @ BKN
# 0022100216, BKN vs. CLE
# 0022100215, ATL vs. BOS
# 0022100215, BOS @ ATL
# 0022100214, DET vs. IND
# 0022100210, BKN vs. GSW
# 0022100211, UTA vs. PHI
# 0022100211, PHI @ UTA
# 0022100210, GSW @ BKN
# 0022100212, LAC vs. SAS
# 0022100212, SAS @ LAC
# 0022100200, SAC @ DET
# 0022100200, DET vs. SAC
# 0022100199, BOS @ CLE
# 0022100204, DEN @ DAL
# 0022100204, DAL vs. DEN
# 0022100209, CHI @ LAL
# 0022100209, LAL vs. CHI
# 0022100208, TOR @ POR
# 0022100208, POR vs. TOR
# 0022100206, MIN vs. PHX
# 0022100206, PHX @ MIN
# 0022100207, OKC vs. MIA
# 0022100207, MIA @ OKC
# 0022100205, HOU @ MEM
# 0022100205, MEM vs. HOU
# 0022100202, ORL @ ATL
# 0022100202, ATL vs. ORL
# 0022100203, IND @ NYK
# 0022100203, NYK vs. IND
# 0022100201, WAS vs. NOP
# 0022100199, CLE vs. BOS
# 0022100201, NOP @ WAS
# 0022100197, DEN vs. POR
# 0022100197, POR @ DEN
# 0022100194, CHA vs. GSW
# 0022100194, GSW @ CHA
# 0022100195, HOU vs. PHX
# 0022100195, PHX @ HOU
# 0022100196, OKC vs. BKN
# 0022100196, BKN @ OKC
# 0022100198, LAC vs. CHI
# 0022100198, CHI @ LAC
# 0022100193, ATL vs. MIL
# 0022100193, MIL @ ATL
# 0022100192, SAS @ LAL
# 0022100192, LAL vs. SAS
# 0022100191, MIN @ LAC
# 0022100191, LAC vs. MIN
# 0022100190, CLE vs. BOS
# 0022100185, MIA @ UTA
# 0022100185, UTA vs. MIA
# 0022100190, BOS @ CLE
# 0022100187, WAS @ ORL
# 0022100189, TOR vs. DET
# 0022100189, DET @ TOR
# 0022100186, IND vs. PHI
# 0022100186, PHI @ IND
# 0022100188, NOP vs. MEM
# 0022100188, MEM @ NOP
# 0022100187, ORL vs. WAS
# 0022100174, CHA vs. NYK
# 0022100174, NYK @ CHA
# 0022100184, MIN @ LAL
# 0022100184, LAL vs. MIN
# 0022100177, HOU vs. POR
# 0022100177, POR @ HOU
# 0022100179, NOP vs. BKN
# 0022100179, BKN @ NOP
# 0022100180, SAC @ OKC
# 0022100180, OKC vs. SAC
# 0022100178, MEM vs. PHX
# 0022100178, PHX @ MEM
# 0022100175, BOS vs. MIL
# 0022100175, MIL @ BOS
# 0022100176, DET @ CLE
# 0022100176, CLE vs. DET
# 0022100181, SAS vs. DAL
# 0022100183, CHI @ GSW
# 0022100183, GSW vs. CHI
# 0022100182, ATL @ DEN
# 0022100182, DEN vs. ATL
# 0022100181, DAL @ SAS
# 0022100171, PHI vs. TOR
# 0022100171, TOR @ PHI
# 0022100172, UTA vs. IND
# 0022100172, IND @ UTA
# 0022100173, MIA @ LAC
# 0022100173, LAC vs. MIA
# 0022100168, PHX vs. POR
# 0022100168, POR @ PHX
# 0022100167, IND @ DEN
# 0022100169, GSW vs. MIN
# 0022100169, MIN @ GSW
# 0022100167, DEN vs. IND
# 0022100170, MIA @ LAL
# 0022100170, LAL vs. MIA
# 0022100158, CLE vs. WAS
# 0022100160, BOS vs. TOR
# 0022100160, TOR @ BOS
# 0022100159, BKN @ ORL
# 0022100159, ORL vs. BKN
# 0022100162, HOU vs. DET
# 0022100162, DET @ HOU
# 0022100158, WAS @ CLE
# 0022100161, MIL @ NYK
# 0022100161, NYK vs. MIL
# 0022100163, DAL @ CHI
# 0022100163, CHI vs. DAL
# 0022100164, CHA @ MEM
# 0022100164, MEM vs. CHA
# 0022100166, SAS vs. SAC
# 0022100166, SAC @ SAS
# 0022100165, NOP vs. OKC
# 0022100165, OKC @ NOP
# 0022100157, POR @ LAC
# 0022100157, LAC vs. POR
# 0022100156, UTA vs. ATL
# 0022100156, ATL @ UTA
# 0022100155, PHI vs. MIL
# 0022100155, MIL @ PHI
# 0022100147, PHI vs. NYK
# 0022100147, NYK @ PHI
# 0022100154, CHA @ LAL
# 0022100154, LAL vs. CHA
# 0022100153, SAC vs. PHX
# 0022100153, PHX @ SAC
# 0022100152, ATL @ GSW
# 0022100152, GSW vs. ATL
# 0022100151, DEN vs. MIA
# 0022100151, MIA @ DEN
# 0022100149, MEM vs. MIN
# 0022100149, MIN @ MEM
# 0022100150, DAL vs. NOP
# 0022100150, NOP @ DAL
# 0022100148, BKN @ CHI
# 0022100148, CHI vs. BKN
# 0022100144, SAS @ OKC
# 0022100145, GSW vs. HOU
# 0022100145, HOU @ GSW
# 0022100146, CHA @ LAC
# 0022100146, LAC vs. CHA
# 0022100144, OKC vs. SAS
# 0022100143, SAC vs. IND
# 0022100143, IND @ SAC
# 0022100139, BKN @ TOR
# 0022100139, TOR vs. BKN
# 0022100140, NYK vs. CLE
# 0022100140, CLE @ NYK
# 0022100142, WAS vs. MIL
# 0022100142, MIL @ WAS
# 0022100141, ORL vs. UTA
# 0022100141, UTA @ ORL
# 0022100134, MIA vs. UTA
# 0022100137, ATL @ PHX
# 0022100137, PHX vs. ATL
# 0022100136, BOS @ DAL
# 0022100136, DAL vs. BOS
# 0022100134, UTA @ MIA
# 0022100135, PHI @ CHI
# 0022100135, CHI vs. PHI
# 0022100138, LAL @ POR
# 0022100133, DEN vs. HOU
# 0022100133, HOU @ DEN
# 0022100138, POR vs. LAL
# 0022100130, NOP @ GSW
# 0022100124, BKN @ DET
# 0022100124, DET vs. BKN
# 0022100130, GSW vs. NOP
# 0022100125, SAS @ ORL
# 0022100125, ORL vs. SAS
# 0022100126, WAS vs. MEM
# 0022100126, MEM @ WAS
# 0022100127, CLE @ TOR
# 0022100127, TOR vs. CLE
# 0022100128, MIL vs. NYK
# 0022100128, NYK @ MIL
# 0022100132, SAC vs. CHA
# 0022100129, MIN vs. LAC
# 0022100129, LAC @ MIN
# 0022100132, CHA @ SAC
# 0022100131, IND @ POR
# 0022100131, POR vs. IND
# 0022100123, LAL vs. OKC
# 0022100123, OKC @ LAL
# 0022100122, HOU @ PHX
# 0022100122, PHX vs. HOU
# 0022100121, BOS @ MIA
# 0022100121, MIA vs. BOS
# 0022100120, ATL vs. UTA
# 0022100120, UTA @ ATL
# 0022100119, DET vs. PHI
# 0022100119, PHI @ DET
# 0022100110, BOS @ ORL
# 0022100110, ORL vs. BOS
# 0022100108, POR @ CLE
# 0022100108, CLE vs. POR
# 0022100111, CHI @ PHI
# 0022100111, PHI vs. CHI
# 0022100112, WAS vs. TOR
# 0022100109, IND vs. NYK
# 0022100117, CHA @ GSW
# 0022100117, GSW vs. CHA
# 0022100118, NOP @ SAC
# 0022100109, NYK @ IND
# 0022100118, SAC vs. NOP
# 0022100116, SAS vs. DAL
# 0022100112, TOR @ WAS
# 0022100113, BKN vs. ATL
# 0022100113, ATL @ BKN
# 0022100115, LAC @ MIN
# 0022100115, MIN vs. LAC
# 0022100114, DEN @ MEM
# 0022100116, DAL @ SAS
# 0022100114, MEM vs. DEN
# 0022100107, HOU @ LAL
# 0022100107, LAL vs. HOU
# 0022100106, PHX vs. NOP
# 0022100106, NOP @ PHX
# 0022100105, SAC @ UTA
# 0022100105, UTA vs. SAC
# 0022100104, DAL vs. MIA
# 0022100104, MIA @ DAL
# 0022100103, DET vs. MIL
# 0022100103, MIL @ DET
# 0022100095, IND vs. SAS
# 0022100095, SAS @ IND
# 0022100096, PHI vs. POR
# 0022100096, POR @ PHI
# 0022100094, CLE @ CHA
# 0022100094, CHA vs. CLE
# 0022100098, CHI @ BOS
# 0022100098, BOS vs. CHI
# 0022100097, ATL vs. WAS
# 0022100097, WAS @ ATL
# 0022100100, MEM vs. DEN
# 0022100100, DEN @ MEM
# 0022100101, MIN vs. ORL
# 0022100101, ORL @ MIN
# 0022100102, OKC @ LAC
# 0022100102, LAC vs. OKC
# 0022100099, NYK vs. TOR
# 0022100099, TOR @ NYK
# 0022100090, POR @ CHA
# 0022100090, CHA vs. POR
# 0022100091, UTA @ MIL
# 0022100089, SAC @ DAL
# 0022100093, HOU @ LAL
# 0022100093, LAL vs. HOU
# 0022100092, DET @ BKN
# 0022100092, BKN vs. DET
# 0022100091, MIL vs. UTA
# 0022100089, DAL vs. SAC
# 0022100078, BOS @ WAS
# 0022100078, WAS vs. BOS
# 0022100079, DET vs. ORL
# 0022100079, ORL @ DET
# 0022100080, NYK @ NOP
# 0022100080, NOP vs. NYK
# 0022100081, IND vs. TOR
# 0022100081, TOR @ IND
# 0022100088, CLE @ PHX
# 0022100088, PHX vs. CLE
# 0022100087, MIN vs. DEN
# 0022100087, DEN @ MIN
# 0022100086, OKC @ GSW
# 0022100086, GSW vs. OKC
# 0022100083, CHI vs. UTA
# 0022100083, UTA @ CHI
# 0022100085, SAS @ MIL
# 0022100085, MIL vs. SAS
# 0022100082, PHI vs. ATL
# 0022100082, ATL @ PHI
# 0022100084, MEM vs. MIA
# 0022100084, MIA @ MEM
# 0022100071, ORL @ TOR
# 0022100071, TOR vs. ORL
# 0022100073, CHA @ MIA
# 0022100073, MIA vs. CHA
# 0022100072, BKN vs. IND
# 0022100072, IND @ BKN
# 0022100074, NOP vs. SAC
# 0022100074, SAC @ NOP
# 0022100076, LAC @ POR
# 0022100076, POR vs. LAC
# 0022100075, DEN vs. DAL
# 0022100075, DAL @ DEN
# 0022100077, CLE @ LAL
# 0022100077, LAL vs. CLE
# 0022100066, WAS vs. ATL
# 0022100066, ATL @ WAS
# 0022100065, PHI vs. DET
# 0022100065, DET @ PHI
# 0022100068, HOU vs. UTA
# 0022100068, UTA @ HOU
# 0022100067, NYK @ CHI
# 0022100067, CHI vs. NYK
# 0022100069, DAL vs. SAS
# 0022100069, SAS @ DAL
# 0022100070, MEM @ GSW
# 0022100070, GSW vs. MEM
# 0022100055, CHA @ ORL
# 0022100055, ORL vs. CHA
# 0022100057, BKN vs. MIA
# 0022100057, MIA @ BKN
# 0022100058, IND @ TOR
# 0022100058, TOR vs. IND
# 0022100056, BOS vs. WAS
# 0022100056, WAS @ BOS
# 0022100059, NOP vs. ATL
# 0022100059, ATL @ NOP
# 0022100060, MIL vs. MIN
# 0022100060, MIN @ MIL
# 0022100061, LAL @ OKC
# 0022100061, OKC vs. LAL
# 0022100062, SAC @ PHX
# 0022100062, PHX vs. SAC
# 0022100064, LAC vs. CLE
# 0022100064, CLE @ LAC
# 0022100063, MEM @ POR
# 0022100063, POR vs. MEM
# 0022100050, PHI @ NYK
# 0022100050, NYK vs. PHI
# 0022100051, GSW @ OKC
# 0022100051, OKC vs. GSW
# 0022100052, HOU @ DAL
# 0022100052, DAL vs. HOU
# 0022100053, LAL @ SAS
# 0022100053, SAS vs. LAL
# 0022100054, UTA vs. DEN
# 0022100054, DEN @ UTA
# 0022100041, BOS @ CHA
# 0022100041, CHA vs. BOS
# 0022100044, BKN vs. WAS
# 0022100044, WAS @ BKN
# 0022100045, MIA vs. ORL
# 0022100045, ORL @ MIA
# 0022100046, CHI @ TOR
# 0022100042, MIL @ IND
# 0022100042, IND vs. MIL
# 0022100043, ATL vs. DET
# 0022100049, POR @ LAC
# 0022100049, LAC vs. POR
# 0022100048, DEN vs. CLE
# 0022100043, DET @ ATL
# 0022100048, CLE @ DEN
# 0022100047, MIN vs. NOP
# 0022100047, NOP @ MIN
# 0022100046, TOR vs. CHI
# 0022100036, ORL @ NYK
# 0022100036, NYK vs. ORL
# 0022100038, PHI @ OKC
# 0022100040, LAL vs. MEM
# 0022100037, HOU vs. BOS
# 0022100037, BOS @ HOU
# 0022100035, CHA @ BKN
# 0022100035, BKN vs. CHA
# 0022100040, MEM @ LAL
# 0022100039, SAC vs. GSW
# 0022100039, GSW @ SAC
# 0022100038, OKC vs. PHI
# 0022100034, MEM @ LAC
# 0022100034, LAC vs. MEM
# 0022100033, POR vs. PHX
# 0022100033, PHX @ POR
# 0022100027, CLE vs. ATL
# 0022100032, SAS vs. MIL
# 0022100032, MIL @ SAS
# 0022100031, NOP @ MIN
# 0022100031, MIN vs. NOP
# 0022100030, DET @ CHI
# 0022100030, CHI vs. DET
# 0022100029, TOR vs. DAL
# 0022100029, DAL @ TOR
# 0022100027, ATL @ CLE
# 0022100028, MIA @ IND
# 0022100028, IND vs. MIA
# 0022100020, BOS vs. TOR
# 0022100020, TOR @ BOS
# 0022100017, CLE vs. CHA
# 0022100017, CHA @ CLE
# 0022100018, NYK @ ORL
# 0022100018, ORL vs. NYK
# 0022100019, WAS vs. IND
# 0022100025, LAL vs. PHX
# 0022100026, SAC vs. UTA
# 0022100026, UTA @ SAC
# 0022100024, DEN vs. SAS
# 0022100024, SAS @ DEN
# 0022100025, PHX @ LAL
# 0022100022, CHI vs. NOP
# 0022100022, NOP @ CHI
# 0022100019, IND @ WAS
# 0022100021, BKN @ PHI
# 0022100021, PHI vs. BKN
# 0022100023, HOU vs. OKC
# 0022100023, OKC @ HOU
# 0022100016, LAC @ GSW
# 0022100016, GSW vs. LAC
# 0022100015, MIL @ MIA
# 0022100015, MIA vs. MIL
# 0022100014, ATL vs. DAL
# 0022100014, DAL @ ATL
# 0022100011, OKC @ UTA
# 0022100011, UTA vs. OKC
# 0022100013, POR vs. SAC
# 0022100013, SAC @ POR
# 0022100012, PHX vs. DEN
# 0022100004, CHI @ DET
# 0022100004, DET vs. CHI
# 0022100003, CHA vs. IND
# 0022100006, TOR vs. WAS
# 0022100012, DEN @ PHX
# 0022100003, IND @ CHA
# 0022100010, SAS vs. ORL
# 0022100010, ORL @ SAS
# 0022100005, BOS @ NYK
# 0022100005, NYK vs. BOS
# 0022100008, MIN vs. HOU
# 0022100008, HOU @ MIN
# 0022100007, CLE @ MEM
# 0022100007, MEM vs. CLE
# 0022100009, NOP vs. PHI
# 0022100009, PHI @ NOP
# 0022100006, WAS @ TOR
# 0022100001, BKN @ MIL
# 0022100001, MIL vs. BKN
# 0022100002, LAL vs. GSW
# 0022100002, GSW @ LAL
