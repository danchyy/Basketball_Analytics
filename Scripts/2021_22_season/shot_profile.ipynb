# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tqdm
from nba_api.stats.endpoints.shotchartdetail import ShotChartDetail
import requests
from nba_api.stats.static.players import find_players_by_full_name
from adjustText import adjust_text
from io import BytesIO
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import time
from PIL import Image
from collections import defaultdict

# %%
from nba_api.stats.endpoints.playbyplayv2 import PlayByPlayV2

from nba_api.stats.endpoints.playbyplay import PlayByPlay
from nba_api.stats.endpoints.leaguegamefinder import LeagueGameFinder
from nba_api.stats.static.players import find_players_by_full_name
from nba_api.stats.static.teams import find_teams_by_full_name
from nba_api.stats.endpoints.playergamelogs import PlayerGameLogs
from nba_api.stats.endpoints.boxscoretraditionalv2 import BoxScoreTraditionalV2
from nba_api.stats.endpoints.shotchartdetail import ShotChartDetail

from nba_api.stats.endpoints.leaguedashteamshotlocations import LeagueDashTeamShotLocations
from nba_api.stats.endpoints.leaguedashplayerptshot import LeagueDashPlayerPtShot

from nba_api.stats.endpoints.playerdashboardbyshootingsplits import PlayerDashboardByShootingSplits
from nba_api.stats.endpoints.synergyplaytypes import SynergyPlayTypes
from nba_api.stats.endpoints.leaguedashptstats import LeagueDashPtStats
from nba_api.stats.endpoints.leaguedashplayerstats import LeagueDashPlayerStats

from nba_api.stats.endpoints.leaguehustlestatsplayer import LeagueHustleStatsPlayer
from nba_api.stats.endpoints.leaguedashteamstats import LeagueDashTeamStats

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
last_season = ShotChartDetail(team_id=0, player_id=0, season_type_all_star='Regular Season', season_nullable='2020-21', context_measure_simple='FGA', timeout=300).get_data_frames()[0]

# %%
cur_season = ShotChartDetail(team_id=0, player_id=0, season_type_all_star='Regular Season', season_nullable='2021-22', context_measure_simple='FGA', timeout=300).get_data_frames()[0]

# %%
attempt_counts = last_season.groupby('PLAYER_ID').SHOT_ATTEMPTED_FLAG.sum().reset_index()

# %%
top_40 = attempt_counts.sort_values(by='SHOT_ATTEMPTED_FLAG', ascending=False).iloc[:150]

# %%
top_scorers_last = LeagueDashPlayerStats(season='2020-21', per_mode_detailed='PerGame').get_data_frames()[0]

# %%
filtered_scorers = top_scorers_last.loc[top_scorers_last.GP > 30].sort_values(by='PTS', ascending=False).iloc[:150]

# %%
dont_include = ['Zion Williamson', 'Pascal Siakam', 'John Wall', 'Kyrie Irving']

# %%
filtered_scorers = filtered_scorers.loc[~filtered_scorers.PLAYER_NAME.isin(dont_include)]

# %%
top_scorers_cur = LeagueDashPlayerStats(season='2021-22', per_mode_detailed='PerGame').get_data_frames()[0]

# %%
cur_filtered = top_scorers_cur.loc[top_scorers_cur.GP > 4].sort_values(by='PTS', ascending=False).iloc[:150]

# %%
interesting_ids = list(set(filtered_scorers.PLAYER_ID.tolist()).intersection(set(cur_filtered.PLAYER_ID.tolist())))

# %%
interesting_last = last_season.loc[last_season.PLAYER_ID.isin(interesting_ids)]

# %% [markdown]
# ## Encoding
#
# - focus only on zones for first iteration?
#     -> then on types
#     -> just check the percentages of each zone

# %% [markdown]
# ### Analyzing complex combos

# %%
combinations = last_season.groupby(['SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE']).SHOT_ATTEMPTED_FLAG.sum().index.tolist()

# %%
len(combinations)
# Out:
# 20

# %%
total_shots = interesting_last.groupby(['PLAYER_NAME']).SHOT_ATTEMPTED_FLAG.sum().to_frame().reset_index()

# %%
total_shots = total_shots.rename(
    columns={'SHOT_ATTEMPTED_FLAG': 'TOTAL_SHOTS'}
)

# %%
zone_combo_group = interesting_last.groupby(['PLAYER_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE']).SHOT_ATTEMPTED_FLAG.sum().to_frame()

# %%
zone_combo_group = zone_combo_group.reset_index()

# %%
total_df = pd.merge(left=zone_combo_group, right=total_shots, on='PLAYER_NAME')

# %%
total_df.loc[:, 'ZONE_FREQ'] = (total_df.SHOT_ATTEMPTED_FLAG / total_df.TOTAL_SHOTS * 100).round(2)

# %%
player_names = total_df.PLAYER_NAME.unique().tolist()

entries = []
for name in player_names:
    subset = total_df.loc[total_df.PLAYER_NAME == name]
    for combination in combinations:
        combo_info = subset.loc[(subset.SHOT_ZONE_BASIC == combination[0]) & (subset.SHOT_ZONE_AREA == combination[1])
                        & (subset.SHOT_ZONE_RANGE == combination[2])]
        if len(combo_info) == 0:
            entries.append(
            {
                'PLAYER_NAME': name,
                'SHOT_ZONE_BASIC': combination[0],
                'SHOT_ZONE_AREA': combination[1],
                'SHOT_ZONE_RANGE': combination[2],
                'SHOT_ATTEMPTED_FLAG': 0,
                'TOTAL_SHOTS': subset.iloc[0].TOTAL_SHOTS,
                'ZONE_FREQ': 0.0
            })

# %%
empty_combos = pd.DataFrame(entries)

# %%
total_df = pd.concat([total_df, empty_combos])

# %%
total_df = total_df.sort_values(by=['PLAYER_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE']).reset_index()

# %%
total_df = total_df.loc[:, total_df.columns.tolist()[1:]]

# %% [markdown]
# #### Current season

# %%
interesting_cur = cur_season.loc[cur_season.PLAYER_ID.isin(interesting_ids)]

# %%
cur_total_shots = interesting_cur.groupby(['PLAYER_NAME']).SHOT_ATTEMPTED_FLAG.sum().to_frame().reset_index()

# %%
cur_total_shots = cur_total_shots.rename(
    columns={'SHOT_ATTEMPTED_FLAG': 'TOTAL_SHOTS'}
)

# %%
cur_zone_combo_group = interesting_cur.groupby(['PLAYER_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE']).SHOT_ATTEMPTED_FLAG.sum().to_frame()

# %%
cur_zone_combo_group = cur_zone_combo_group.reset_index()

# %%
cur_totals = cur_zone_combo_group.groupby(['PLAYER_NAME']).SHOT_ATTEMPTED_FLAG.sum().to_frame().reset_index()

cur_totals = cur_totals.rename(
    columns={'SHOT_ATTEMPTED_FLAG': 'TOTAL_SHOTS'}
)
cur_total = pd.merge(left=cur_zone_combo_group, right=cur_totals, on='PLAYER_NAME')

# %%
cur_total.loc[:, 'ZONE_FREQ'] = (cur_total.SHOT_ATTEMPTED_FLAG / cur_total.TOTAL_SHOTS * 100).round(2)

# %%
player_names = cur_total.PLAYER_NAME.unique().tolist()

cur_entries = []
for name in player_names:
    subset = cur_total.loc[cur_total.PLAYER_NAME == name]
    for combination in combinations:
        combo_info = subset.loc[(subset.SHOT_ZONE_BASIC == combination[0]) & (subset.SHOT_ZONE_AREA == combination[1])
                        & (subset.SHOT_ZONE_RANGE == combination[2])]
        if len(combo_info) == 0:
            cur_entries.append(
            {
                'PLAYER_NAME': name,
                'SHOT_ZONE_BASIC': combination[0],
                'SHOT_ZONE_AREA': combination[1],
                'SHOT_ZONE_RANGE': combination[2],
                'SHOT_ATTEMPTED_FLAG': 0,
                'TOTAL_SHOTS': subset.iloc[0].TOTAL_SHOTS,
                'ZONE_FREQ': 0.0
            })

# %%
empty_combos = pd.DataFrame(cur_entries)

cur_total = pd.concat([cur_total, empty_combos])

cur_total = cur_total.sort_values(by=['PLAYER_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE'])
cur_total = cur_total.reset_index()
cur_total = cur_total.loc[:, cur_total.columns.tolist()[1:]]

# %% [markdown]
# ### Merging

# %%
merged_df = pd.merge(left=total_df, right=cur_total, on=['PLAYER_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE'], suffixes=('_LAST', '_CUR'))

# %%
davis_data = merged_df.loc[merged_df.PLAYER_NAME == 'Anthony Davis']

# %%
davis_data
# Out:
#       PLAYER_NAME        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 60  Anthony Davis      Above the Break 3         Back Court(BC)
# 61  Anthony Davis      Above the Break 3              Center(C)
# 62  Anthony Davis      Above the Break 3   Left Side Center(LC)
# 63  Anthony Davis      Above the Break 3  Right Side Center(RC)
# 64  Anthony Davis              Backcourt         Back Court(BC)
# 65  Anthony Davis  In The Paint (Non-RA)              Center(C)
# 66  Anthony Davis  In The Paint (Non-RA)              Center(C)
# 67  Anthony Davis  In The Paint (Non-RA)           Left Side(L)
# 68  Anthony Davis  In The Paint (Non-RA)          Right Side(R)
# 69  Anthony Davis          Left Corner 3           Left Side(L)
# 70  Anthony Davis              Mid-Range              Center(C)
# 71  Anthony Davis              Mid-Range              Center(C)
# 72  Anthony Davis              Mid-Range   Left Side Center(LC)
# 73  Anthony Davis              Mid-Range           Left Side(L)
# 74  Anthony Davis              Mid-Range           Left Side(L)
# 75  Anthony Davis              Mid-Range  Right Side Center(RC)
# 76  Anthony Davis              Mid-Range          Right Side(R)
# 77  Anthony Davis              Mid-Range          Right Side(R)
# 78  Anthony Davis        Restricted Area              Center(C)
# 79  Anthony Davis         Right Corner 3          Right Side(R)
#
#     SHOT_ZONE_RANGE  SHOT_ATTEMPTED_FLAG_LAST  TOTAL_SHOTS_LAST  \
# 60  Back Court Shot                         0               613
# 61          24+ ft.                        20               613
# 62          24+ ft.                        34               613
# 63          24+ ft.                        29               613
# 64  Back Court Shot                         1               613
# 65         8-16 ft.                        59               613
# 66  Less Than 8 ft.                        75               613
# 67         8-16 ft.                        11               613
# 68         8-16 ft.                        12               613
# 69          24+ ft.                         8               613
# 70        16-24 ft.                        19               613
# 71         8-16 ft.                         9               613
# 72        16-24 ft.                        34               613
# 73        16-24 ft.                        11               613
# 74         8-16 ft.                        58               613
# 75        16-24 ft.                        23               613
# 76        16-24 ft.                         8               613
# 77         8-16 ft.                        22               613
# 78  Less Than 8 ft.                       172               613
# 79          24+ ft.                         8               613
#
#     ZONE_FREQ_LAST  SHOT_ATTEMPTED_FLAG_CUR  TOTAL_SHOTS_CUR  ZONE_FREQ_CUR
# 60            0.00                        0              374           0.00
# 61            3.26                       10              374           2.67
# 62            5.55                       12              374           3.21
# 63            4.73                       17              374           4.55
# 64            0.16                        0              374           0.00
# 65            9.62                       27              374           7.22
# 66           12.23                       33              374           8.82
# 67            1.79                        5              374           1.34
# 68            1.96                        3              374           0.80
# 69            1.31                        2              374           0.53
# 70            3.10                       26              374           6.95
# 71            1.47                        4              374           1.07
# 72            5.55                       26              374           6.95
# 73            1.79                        3              374           0.80
# 74            9.46                       24              374           6.42
# 75            3.75                       15              374           4.01
# 76            1.31                        3              374           0.80
# 77            3.59                        6              374           1.60
# 78           28.06                      157              374          41.98
# 79            1.31                        1              374           0.27

# %%
davis_data.loc[:, ['PLAYER_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'TOTAL_SHOTS_LAST', 'ZONE_FREQ_LAST', 'TOTAL_SHOTS_CUR', 'ZONE_FREQ_CUR']]
# Out:
#       PLAYER_NAME        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 60  Anthony Davis      Above the Break 3         Back Court(BC)
# 61  Anthony Davis      Above the Break 3              Center(C)
# 62  Anthony Davis      Above the Break 3   Left Side Center(LC)
# 63  Anthony Davis      Above the Break 3  Right Side Center(RC)
# 64  Anthony Davis              Backcourt         Back Court(BC)
# 65  Anthony Davis  In The Paint (Non-RA)              Center(C)
# 66  Anthony Davis  In The Paint (Non-RA)              Center(C)
# 67  Anthony Davis  In The Paint (Non-RA)           Left Side(L)
# 68  Anthony Davis  In The Paint (Non-RA)          Right Side(R)
# 69  Anthony Davis          Left Corner 3           Left Side(L)
# 70  Anthony Davis              Mid-Range              Center(C)
# 71  Anthony Davis              Mid-Range              Center(C)
# 72  Anthony Davis              Mid-Range   Left Side Center(LC)
# 73  Anthony Davis              Mid-Range           Left Side(L)
# 74  Anthony Davis              Mid-Range           Left Side(L)
# 75  Anthony Davis              Mid-Range  Right Side Center(RC)
# 76  Anthony Davis              Mid-Range          Right Side(R)
# 77  Anthony Davis              Mid-Range          Right Side(R)
# 78  Anthony Davis        Restricted Area              Center(C)
# 79  Anthony Davis         Right Corner 3          Right Side(R)
#
#     SHOT_ZONE_RANGE  TOTAL_SHOTS_LAST  ZONE_FREQ_LAST  TOTAL_SHOTS_CUR  \
# 60  Back Court Shot               613            0.00              374
# 61          24+ ft.               613            3.26              374
# 62          24+ ft.               613            5.55              374
# 63          24+ ft.               613            4.73              374
# 64  Back Court Shot               613            0.16              374
# 65         8-16 ft.               613            9.62              374
# 66  Less Than 8 ft.               613           12.23              374
# 67         8-16 ft.               613            1.79              374
# 68         8-16 ft.               613            1.96              374
# 69          24+ ft.               613            1.31              374
# 70        16-24 ft.               613            3.10              374
# 71         8-16 ft.               613            1.47              374
# 72        16-24 ft.               613            5.55              374
# 73        16-24 ft.               613            1.79              374
# 74         8-16 ft.               613            9.46              374
# 75        16-24 ft.               613            3.75              374
# 76        16-24 ft.               613            1.31              374
# 77         8-16 ft.               613            3.59              374
# 78  Less Than 8 ft.               613           28.06              374
# 79          24+ ft.               613            1.31              374
#
#     ZONE_FREQ_CUR
# 60           0.00
# 61           2.67
# 62           3.21
# 63           4.55
# 64           0.00
# 65           7.22
# 66           8.82
# 67           1.34
# 68           0.80
# 69           0.53
# 70           6.95
# 71           1.07
# 72           6.95
# 73           0.80
# 74           6.42
# 75           4.01
# 76           0.80
# 77           1.60
# 78          41.98
# 79           0.27

# %%
def cosine_similarity(first, second):
    if len(first) != len(second):
        print("ERROR")
        return None
    dot = np.dot(first, second)
    return dot / ((sum([item ** 2 for item in first]) ** 0.5) * (sum([item ** 2 for item in second]) ** 0.5))

# %%
player_names = merged_df.PLAYER_NAME.unique().tolist()

# %%
merged_df.loc[merged_df.PLAYER_NAME == 'Stephen Curry']
# Out:
#         PLAYER_NAME        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 2000  Stephen Curry      Above the Break 3         Back Court(BC)
# 2001  Stephen Curry      Above the Break 3              Center(C)
# 2002  Stephen Curry      Above the Break 3   Left Side Center(LC)
# 2003  Stephen Curry      Above the Break 3  Right Side Center(RC)
# 2004  Stephen Curry              Backcourt         Back Court(BC)
# 2005  Stephen Curry  In The Paint (Non-RA)              Center(C)
# 2006  Stephen Curry  In The Paint (Non-RA)              Center(C)
# 2007  Stephen Curry  In The Paint (Non-RA)           Left Side(L)
# 2008  Stephen Curry  In The Paint (Non-RA)          Right Side(R)
# 2009  Stephen Curry          Left Corner 3           Left Side(L)
# 2010  Stephen Curry              Mid-Range              Center(C)
# 2011  Stephen Curry              Mid-Range              Center(C)
# 2012  Stephen Curry              Mid-Range   Left Side Center(LC)
# 2013  Stephen Curry              Mid-Range           Left Side(L)
# 2014  Stephen Curry              Mid-Range           Left Side(L)
# 2015  Stephen Curry              Mid-Range  Right Side Center(RC)
# 2016  Stephen Curry              Mid-Range          Right Side(R)
# 2017  Stephen Curry              Mid-Range          Right Side(R)
# 2018  Stephen Curry        Restricted Area              Center(C)
# 2019  Stephen Curry         Right Corner 3          Right Side(R)
#
#       SHOT_ZONE_RANGE  SHOT_ATTEMPTED_FLAG_LAST  TOTAL_SHOTS_LAST  \
# 2000  Back Court Shot                         1              1365
# 2001          24+ ft.                       187              1365
# 2002          24+ ft.                       250              1365
# 2003          24+ ft.                       287              1365
# 2004  Back Court Shot                        11              1365
# 2005         8-16 ft.                        56              1365
# 2006  Less Than 8 ft.                        87              1365
# 2007         8-16 ft.                         7              1365
# 2008         8-16 ft.                         8              1365
# 2009          24+ ft.                        32              1365
# 2010        16-24 ft.                        17              1365
# 2011         8-16 ft.                        10              1365
# 2012        16-24 ft.                        31              1365
# 2013        16-24 ft.                         9              1365
# 2014         8-16 ft.                        11              1365
# 2015        16-24 ft.                        31              1365
# 2016        16-24 ft.                         8              1365
# 2017         8-16 ft.                        23              1365
# 2018  Less Than 8 ft.                       268              1365
# 2019          24+ ft.                        31              1365
#
#       ZONE_FREQ_LAST  SHOT_ATTEMPTED_FLAG_CUR  TOTAL_SHOTS_CUR  ZONE_FREQ_CUR
# 2000            0.07                        0              362           0.00
# 2001           13.70                       57              362          15.75
# 2002           18.32                       85              362          23.48
# 2003           21.03                       72              362          19.89
# 2004            0.81                        0              362           0.00
# 2005            4.10                        5              362           1.38
# 2006            6.37                       21              362           5.80
# 2007            0.51                        3              362           0.83
# 2008            0.59                        0              362           0.00
# 2009            2.34                        9              362           2.49
# 2010            1.25                        4              362           1.10
# 2011            0.73                        4              362           1.10
# 2012            2.27                        3              362           0.83
# 2013            0.66                        1              362           0.28
# 2014            0.81                        4              362           1.10
# 2015            2.27                        2              362           0.55
# 2016            0.59                        4              362           1.10
# 2017            1.68                        6              362           1.66
# 2018           19.63                       71              362          19.61
# 2019            2.27                       11              362           3.04

# %%
cosine_entries = []
for name in player_names:
    subset = merged_df.loc[merged_df.PLAYER_NAME == name]
    cosine = cosine_similarity(subset.ZONE_FREQ_LAST.to_numpy(), subset.ZONE_FREQ_CUR.to_numpy())
    print(f"Player: {name}, Cosine Similarity: {round(cosine, 4)}")
    cosine_entries.append(
        {
            'PLAYER_NAME': name,
            'COSINE_SIMILARITY': round(cosine, 4)
        }
    )
# Out:
# Player: Aaron Gordon, Cosine Similarity: 0.9674
# Player: Alec Burks, Cosine Similarity: 0.9612
# Player: Andrew Wiggins, Cosine Similarity: 0.9832
# Player: Anthony Davis, Cosine Similarity: 0.9542
# Player: Anthony Edwards, Cosine Similarity: 0.9881
# Player: Bam Adebayo, Cosine Similarity: 0.997
# Player: Bobby Portis, Cosine Similarity: 0.954
# Player: Bogdan Bogdanovic, Cosine Similarity: 0.9667
# Player: Bojan Bogdanovic, Cosine Similarity: 0.9709
# Player: Bradley Beal, Cosine Similarity: 0.9847
# Player: Brandon Ingram, Cosine Similarity: 0.9691
# Player: Buddy Hield, Cosine Similarity: 0.9927
# Player: CJ McCollum, Cosine Similarity: 0.9805
# Player: Caris LeVert, Cosine Similarity: 0.9723
# Player: Carmelo Anthony, Cosine Similarity: 0.8914
# Player: Chris Paul, Cosine Similarity: 0.9565
# Player: Christian Wood, Cosine Similarity: 0.9924
# Player: Clint Capela, Cosine Similarity: 0.9999
# Player: Cole Anthony, Cosine Similarity: 0.9326
# Player: Collin Sexton, Cosine Similarity: 0.9684
# Player: D'Angelo Russell, Cosine Similarity: 0.9437
# Player: Damian Lillard, Cosine Similarity: 0.9904
# Player: Darius Garland, Cosine Similarity: 0.9251
# Player: De'Aaron Fox, Cosine Similarity: 0.9825
# Player: DeMar DeRozan, Cosine Similarity: 0.9675
# Player: Deandre Ayton, Cosine Similarity: 0.9932
# Player: Dejounte Murray, Cosine Similarity: 0.9837
# Player: Dennis Schroder, Cosine Similarity: 0.9766
# Player: Derrick Rose, Cosine Similarity: 0.9648
# Player: Derrick White, Cosine Similarity: 0.9374
# Player: Devin Booker, Cosine Similarity: 0.9488
# Player: Devonte' Graham, Cosine Similarity: 0.9762
# Player: Dillon Brooks, Cosine Similarity: 0.9696
# Player: Domantas Sabonis, Cosine Similarity: 0.9908
# Player: Donovan Mitchell, Cosine Similarity: 0.995
# Player: Doug McDermott, Cosine Similarity: 0.8821
# Player: Duncan Robinson, Cosine Similarity: 0.9616
# Player: Evan Fournier, Cosine Similarity: 0.9704
# Player: Fred VanVleet, Cosine Similarity: 0.9737
# Player: Gary Trent Jr., Cosine Similarity: 0.9768
# Player: Giannis Antetokounmpo, Cosine Similarity: 0.9947
# Player: Gordon Hayward, Cosine Similarity: 0.9829
# Player: Harrison Barnes, Cosine Similarity: 0.9931
# Player: Ja Morant, Cosine Similarity: 0.9946
# Player: Jae'Sean Tate, Cosine Similarity: 0.9974
# Player: Jalen Brunson, Cosine Similarity: 0.9814
# Player: James Harden, Cosine Similarity: 0.9751
# Player: Jarrett Allen, Cosine Similarity: 0.9969
# Player: Jaylen Brown, Cosine Similarity: 0.9892
# Player: Jayson Tatum, Cosine Similarity: 0.9932
# Player: Jerami Grant, Cosine Similarity: 0.9799
# Player: Jimmy Butler, Cosine Similarity: 0.9774
# Player: Joe Harris, Cosine Similarity: 0.9658
# Player: Joel Embiid, Cosine Similarity: 0.9347
# Player: John Collins, Cosine Similarity: 0.9924
# Player: Jonas Valanciunas, Cosine Similarity: 0.9747
# Player: Jordan Clarkson, Cosine Similarity: 0.9885
# Player: Jordan Poole, Cosine Similarity: 0.9709
# Player: Jrue Holiday, Cosine Similarity: 0.9594
# Player: Julius Randle, Cosine Similarity: 0.9606
# Player: Jusuf Nurkic, Cosine Similarity: 0.9936
# Player: Karl-Anthony Towns, Cosine Similarity: 0.9939
# Player: Keldon Johnson, Cosine Similarity: 0.9284
# Player: Kelly Olynyk, Cosine Similarity: 0.9767
# Player: Kelly Oubre Jr., Cosine Similarity: 0.947
# Player: Kemba Walker, Cosine Similarity: 0.976
# Player: Kevin Durant, Cosine Similarity: 0.9711
# Player: Khris Middleton, Cosine Similarity: 0.9531
# Player: Kristaps Porzingis, Cosine Similarity: 0.9882
# Player: Kyle Kuzma, Cosine Similarity: 0.9579
# Player: Kyle Lowry, Cosine Similarity: 0.9603
# Player: LaMelo Ball, Cosine Similarity: 0.9746
# Player: Lauri Markkanen, Cosine Similarity: 0.9841
# Player: LeBron James, Cosine Similarity: 0.9783
# Player: Lonnie Walker IV, Cosine Similarity: 0.9657
# Player: Lonzo Ball, Cosine Similarity: 0.9646
# Player: Luguentz Dort, Cosine Similarity: 0.9844
# Player: Luka Doncic, Cosine Similarity: 0.9483
# Player: Malcolm Brogdon, Cosine Similarity: 0.9692
# Player: Malik Beasley, Cosine Similarity: 0.8898
# Player: Marcus Smart, Cosine Similarity: 0.9392
# Player: Mikal Bridges, Cosine Similarity: 0.979
# Player: Mike Conley, Cosine Similarity: 0.9699
# Player: Miles Bridges, Cosine Similarity: 0.979
# Player: Montrezl Harrell, Cosine Similarity: 0.9968
# Player: Myles Turner, Cosine Similarity: 0.9558
# Player: Nikola Jokic, Cosine Similarity: 0.962
# Player: Nikola Vucevic, Cosine Similarity: 0.9758
# Player: Norman Powell, Cosine Similarity: 0.9869
# Player: OG Anunoby, Cosine Similarity: 0.9631
# Player: Paul George, Cosine Similarity: 0.9791
# Player: RJ Barrett, Cosine Similarity: 0.9803
# Player: Richaun Holmes, Cosine Similarity: 0.9904
# Player: Rudy Gay, Cosine Similarity: 0.9144
# Player: Rudy Gobert, Cosine Similarity: 0.9997
# Player: Russell Westbrook, Cosine Similarity: 0.9438
# Player: Saddiq Bey, Cosine Similarity: 0.9057
# Player: Seth Curry, Cosine Similarity: 0.9732
# Player: Shai Gilgeous-Alexander, Cosine Similarity: 0.9237
# Player: Shake Milton, Cosine Similarity: 0.967
# Player: Stephen Curry, Cosine Similarity: 0.9868
# Player: Terry Rozier, Cosine Similarity: 0.9768
# Player: Tim Hardaway Jr., Cosine Similarity: 0.9685
# Player: Tobias Harris, Cosine Similarity: 0.9753
# Player: Trae Young, Cosine Similarity: 0.979
# Player: Tyler Herro, Cosine Similarity: 0.9293
# Player: Tyrese Haliburton, Cosine Similarity: 0.9705
# Player: Wendell Carter Jr., Cosine Similarity: 0.9023
# Player: Will Barton, Cosine Similarity: 0.9892
# Player: Zach LaVine, Cosine Similarity: 0.9884

# %%
cosine_df = pd.DataFrame(cosine_entries)

# %%
sorted_df = cosine_df.sort_values(by='COSINE_SIMILARITY')

# %%
sorted_df.iloc[:30]
# Out:
#                  PLAYER_NAME  COSINE_SIMILARITY
# 35            Doug McDermott             0.8821
# 79             Malik Beasley             0.8898
# 14           Carmelo Anthony             0.8914
# 107       Wendell Carter Jr.             0.9023
# 96                Saddiq Bey             0.9057
# 93                  Rudy Gay             0.9144
# 98   Shai Gilgeous-Alexander             0.9237
# 22            Darius Garland             0.9251
# 62            Keldon Johnson             0.9284
# 105              Tyler Herro             0.9293
# 18              Cole Anthony             0.9326
# 53               Joel Embiid             0.9347
# 29             Derrick White             0.9374
# 80              Marcus Smart             0.9392
# 20          D'Angelo Russell             0.9437
# 95         Russell Westbrook             0.9438
# 64           Kelly Oubre Jr.             0.9470
# 77               Luka Doncic             0.9483
# 30              Devin Booker             0.9488
# 67           Khris Middleton             0.9531
# 6               Bobby Portis             0.9540
# 3              Anthony Davis             0.9542
# 85              Myles Turner             0.9558
# 15                Chris Paul             0.9565
# 69                Kyle Kuzma             0.9579
# 58              Jrue Holiday             0.9594
# 70                Kyle Lowry             0.9603
# 59             Julius Randle             0.9606
# 1                 Alec Burks             0.9612
# 36           Duncan Robinson             0.9616

# %%
sorted_players_top_20 = sorted_df.iloc[:20].reset_index().loc[:, ['PLAYER_NAME', 'COSINE_SIMILARITY']]

# %%
sorted_players_top_20.loc[:, 'RANK'] = [i for i in range(1, len(sorted_players_top_20)+1)]

# %%
sorted_players_top_20.loc[:, ['RANK', 'PLAYER_NAME', 'COSINE_SIMILARITY']]
# Out:
#     RANK              PLAYER_NAME  COSINE_SIMILARITY
# 0      1           Doug McDermott             0.8821
# 1      2            Malik Beasley             0.8898
# 2      3          Carmelo Anthony             0.8914
# 3      4       Wendell Carter Jr.             0.9023
# 4      5               Saddiq Bey             0.9057
# 5      6                 Rudy Gay             0.9144
# 6      7  Shai Gilgeous-Alexander             0.9237
# 7      8           Darius Garland             0.9251
# 8      9           Keldon Johnson             0.9284
# 9     10              Tyler Herro             0.9293
# 10    11             Cole Anthony             0.9326
# 11    12              Joel Embiid             0.9347
# 12    13            Derrick White             0.9374
# 13    14             Marcus Smart             0.9392
# 14    15         D'Angelo Russell             0.9437
# 15    16        Russell Westbrook             0.9438
# 16    17          Kelly Oubre Jr.             0.9470
# 17    18              Luka Doncic             0.9483
# 18    19             Devin Booker             0.9488
# 19    20          Khris Middleton             0.9531

# %% [markdown]
# ## Team change

# %%
last_season = ShotChartDetail(team_id=0, player_id=0, season_type_all_star='Regular Season', season_nullable='2020-21', context_measure_simple='FGA', timeout=300).get_data_frames()[0]

# %%
cur_season = ShotChartDetail(team_id=0, player_id=0, season_type_all_star='Regular Season', season_nullable='2021-22', context_measure_simple='FGA', timeout=300).get_data_frames()[0]

# %%
last_season
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0       Shot Chart Detail  0022000001             12     202681
# 1       Shot Chart Detail  0022000001             13    1630164
# 2       Shot Chart Detail  0022000001             16     201142
# 3       Shot Chart Detail  0022000001             18     203952
# 4       Shot Chart Detail  0022000001             20     201142
# ...                   ...         ...            ...        ...
# 190978  Shot Chart Detail  0022001080            651    1630163
# 190979  Shot Chart Detail  0022001080            660    1629060
# 190980  Shot Chart Detail  0022001080            663     201577
# 190981  Shot Chart Detail  0022001080            673    1628984
# 190982  Shot Chart Detail  0022001080            681    1626179
#
#             PLAYER_NAME     TEAM_ID              TEAM_NAME  PERIOD  \
# 0          Kyrie Irving  1610612751          Brooklyn Nets       1
# 1         James Wiseman  1610612744  Golden State Warriors       1
# 2          Kevin Durant  1610612751          Brooklyn Nets       1
# 3        Andrew Wiggins  1610612744  Golden State Warriors       1
# 4          Kevin Durant  1610612751          Brooklyn Nets       1
# ...                 ...         ...                    ...     ...
# 190978      LaMelo Ball  1610612766      Charlotte Hornets       4
# 190979    Rui Hachimura  1610612764     Washington Wizards       4
# 190980      Robin Lopez  1610612764     Washington Wizards       4
# 190981  Devonte' Graham  1610612766      Charlotte Hornets       4
# 190982     Terry Rozier  1610612766      Charlotte Hornets       4
#
#         MINUTES_REMAINING  SECONDS_REMAINING  ...         SHOT_ZONE_AREA  \
# 0                      11                 22  ...              Center(C)
# 1                      11                 11  ...              Center(C)
# 2                      10                 49  ...              Center(C)
# 3                      10                 31  ...          Right Side(R)
# 4                      10                 23  ...              Center(C)
# ...                   ...                ...  ...                    ...
# 190978                  0                 48  ...           Left Side(L)
# 190979                  0                 24  ...              Center(C)
# 190980                  0                 23  ...              Center(C)
# 190981                  0                 13  ...  Right Side Center(RC)
# 190982                  0                  3  ...  Right Side Center(RC)
#
#         SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0             16-24 ft.            22    -2   220                   1
# 1       Less Than 8 ft.             0     9    -2                   1
# 2               24+ ft.            25   -20   258                   1
# 3               24+ ft.            23   235    46                   1
# 4       Less Than 8 ft.             4    48    13                   1
# ...                 ...           ...   ...   ...                 ...
# 190978          24+ ft.            23  -234    23                   1
# 190979         8-16 ft.            15     5   150                   1
# 190980  Less Than 8 ft.             0     6    -1                   1
# 190981          24+ ft.            25   169   194                   1
# 190982          24+ ft.            25   155   207                   1
#
#         SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                    1   20201222  BKN  GSW
# 1                    1   20201222  BKN  GSW
# 2                    1   20201222  BKN  GSW
# 3                    0   20201222  BKN  GSW
# 4                    1   20201222  BKN  GSW
# ...                ...        ...  ...  ...
# 190978               0   20210516  WAS  CHA
# 190979               0   20210516  WAS  CHA
# 190980               0   20210516  WAS  CHA
# 190981               0   20210516  WAS  CHA
# 190982               0   20210516  WAS  CHA
#
# [190983 rows x 24 columns]

# %%
team_last_combo = last_season.groupby(['TEAM_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE']).SHOT_ATTEMPTED_FLAG.sum().to_frame()

team_last_combo = team_last_combo.reset_index()

last_totals = team_last_combo.groupby(['TEAM_NAME']).SHOT_ATTEMPTED_FLAG.sum().to_frame().reset_index()

last_totals = last_totals.rename(
    columns={'SHOT_ATTEMPTED_FLAG': 'TOTAL_SHOTS'}
)
last_final = pd.merge(left=team_last_combo, right=last_totals, on='TEAM_NAME')

last_final.loc[:, 'ZONE_FREQ'] = (last_final.SHOT_ATTEMPTED_FLAG / last_final.TOTAL_SHOTS * 100).round(2)

# %%
team_cur_combo = cur_season.groupby(['TEAM_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE']).SHOT_ATTEMPTED_FLAG.sum().to_frame()

team_cur_combo = team_cur_combo.reset_index()

cur_totals = team_cur_combo.groupby(['TEAM_NAME']).SHOT_ATTEMPTED_FLAG.sum().to_frame().reset_index()

cur_totals = cur_totals.rename(
    columns={'SHOT_ATTEMPTED_FLAG': 'TOTAL_SHOTS'}
)
cur_final = pd.merge(left=team_cur_combo, right=cur_totals, on='TEAM_NAME')

cur_final.loc[:, 'ZONE_FREQ'] = (cur_final.SHOT_ATTEMPTED_FLAG / cur_final.TOTAL_SHOTS * 100).round(2)

# %%
merged_df = pd.merge(left=last_final, right=cur_final, on=['TEAM_NAME', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE'], suffixes=('_LAST', '_CUR'))

# %%
team_names = cur_final.TEAM_NAME.unique().tolist()

# %%
cosine_entries = []
for name in team_names:
    subset = merged_df.loc[merged_df.TEAM_NAME == name]
    cosine = cosine_similarity(subset.ZONE_FREQ_LAST.to_numpy(), subset.ZONE_FREQ_CUR.to_numpy())
    print(f"Player: {name}, Cosine Similarity: {round(cosine, 4)}")
    cosine_entries.append(
        {
            'PLAYER_NAME': name,
            'COSINE_SIMILARITY': round(cosine, 4)
        }
    )
# Out:
# Player: Atlanta Hawks, Cosine Similarity: 0.9968
# Player: Boston Celtics, Cosine Similarity: 0.9971
# Player: Brooklyn Nets, Cosine Similarity: 0.9866
# Player: Charlotte Hornets, Cosine Similarity: 0.9965
# Player: Chicago Bulls, Cosine Similarity: 0.9918
# Player: Cleveland Cavaliers, Cosine Similarity: 0.9898
# Player: Dallas Mavericks, Cosine Similarity: 0.9939
# Player: Denver Nuggets, Cosine Similarity: 0.9967
# Player: Detroit Pistons, Cosine Similarity: 0.9969
# Player: Golden State Warriors, Cosine Similarity: 0.9937
# Player: Houston Rockets, Cosine Similarity: 0.9924
# Player: Indiana Pacers, Cosine Similarity: 0.9893
# Player: LA Clippers, Cosine Similarity: 0.9941
# Player: Los Angeles Lakers, Cosine Similarity: 0.9912
# Player: Memphis Grizzlies, Cosine Similarity: 0.9962
# Player: Miami Heat, Cosine Similarity: 0.9844
# Player: Milwaukee Bucks, Cosine Similarity: 0.9925
# Player: Minnesota Timberwolves, Cosine Similarity: 0.9909
# Player: New Orleans Pelicans, Cosine Similarity: 0.984
# Player: New York Knicks, Cosine Similarity: 0.9838
# Player: Oklahoma City Thunder, Cosine Similarity: 0.9954
# Player: Orlando Magic, Cosine Similarity: 0.9856
# Player: Philadelphia 76ers, Cosine Similarity: 0.9899
# Player: Phoenix Suns, Cosine Similarity: 0.9943
# Player: Portland Trail Blazers, Cosine Similarity: 0.9955
# Player: Sacramento Kings, Cosine Similarity: 0.9966
# Player: San Antonio Spurs, Cosine Similarity: 0.9881
# Player: Toronto Raptors, Cosine Similarity: 0.989
# Player: Utah Jazz, Cosine Similarity: 0.9986
# Player: Washington Wizards, Cosine Similarity: 0.9887

# %%
cosine_df = pd.DataFrame(cosine_entries)

# %%
cosine_df.sort_values(by='COSINE_SIMILARITY')
# Out:
#                PLAYER_NAME  COSINE_SIMILARITY
# 19         New York Knicks             0.9838
# 18    New Orleans Pelicans             0.9840
# 15              Miami Heat             0.9844
# 21           Orlando Magic             0.9856
# 2            Brooklyn Nets             0.9866
# 26       San Antonio Spurs             0.9881
# 29      Washington Wizards             0.9887
# 27         Toronto Raptors             0.9890
# 11          Indiana Pacers             0.9893
# 5      Cleveland Cavaliers             0.9898
# 22      Philadelphia 76ers             0.9899
# 17  Minnesota Timberwolves             0.9909
# 13      Los Angeles Lakers             0.9912
# 4            Chicago Bulls             0.9918
# 10         Houston Rockets             0.9924
# 16         Milwaukee Bucks             0.9925
# 9    Golden State Warriors             0.9937
# 6         Dallas Mavericks             0.9939
# 12             LA Clippers             0.9941
# 23            Phoenix Suns             0.9943
# 20   Oklahoma City Thunder             0.9954
# 24  Portland Trail Blazers             0.9955
# 14       Memphis Grizzlies             0.9962
# 3        Charlotte Hornets             0.9965
# 25        Sacramento Kings             0.9966
# 7           Denver Nuggets             0.9967
# 0            Atlanta Hawks             0.9968
# 8          Detroit Pistons             0.9969
# 1           Boston Celtics             0.9971
# 28               Utah Jazz             0.9986

# %% [markdown]
# ### Shot tracking change

# %%
from nba_api.stats.endpoints.leaguedashptstats import LeagueDashPtStats

# %%
shot_eff = LeagueDashPtStats(per_mode_simple='PerGame', pt_measure_type='Efficiency', player_or_team='Player', season='2021-22').get_data_frames()[0]

# %%
categories = [
    "CatchShoot", "PullUpShot", "Drives", "ElbowTouch", "PostTouch", "PaintTouch"
]

# %%
shot_eff = LeagueDashPtStats(per_mode_simple='PerGame', pt_measure_type='CatchShoot', player_or_team='Player', season='2021-22').get_data_frames()[0]

# %%
interesting_overall_columns = [
    'PLAYER_ID',
    'PLAYER_NAME',
    'TEAM_ID',
    'TEAM_ABBREVIATION',
    'GP',
    'MIN',
    'FGM',
    'FGA',
    'FG_PCT',
    'FG3M',
    'FG3A',
    'FG3_PCT',
    'PTS',
]

# %%
season = '2021-22'
merged_df = LeagueDashPlayerStats(season=season, per_mode_detailed='PerGame').get_data_frames()[0]
merged_df = merged_df.loc[:, interesting_overall_columns]
for category in categories:
    cur_cat = LeagueDashPtStats(per_mode_simple='PerGame', pt_measure_type=category, player_or_team='Player', season=season).get_data_frames()[0]
    columns = ['PLAYER_ID', 'PLAYER_NAME'] + [
        column for column in cur_cat.columns if 'FGM' in column or 'FGA' in column
    ]
    subset = cur_cat.loc[:, columns]
    merged_df = pd.merge(left=merged_df, right=subset, on=['PLAYER_ID', 'PLAYER_NAME'], how='left')
    merged_df = merged_df.fillna(0.0)
    time.sleep(0.5)

# %%
season = '2020-21'
last_merged_df = LeagueDashPlayerStats(season=season, per_mode_detailed='PerGame').get_data_frames()[0]
last_merged_df = last_merged_df.loc[:, interesting_overall_columns]
for category in categories:
    cur_cat = LeagueDashPtStats(per_mode_simple='PerGame', pt_measure_type=category, player_or_team='Player', season=season).get_data_frames()[0]
    columns = ['PLAYER_ID', 'PLAYER_NAME'] + [
        column for column in cur_cat.columns if 'FGM' in column or 'FGA' in column
    ]
    subset = cur_cat.loc[:, columns]
    last_merged_df = pd.merge(left=last_merged_df, right=subset, on=['PLAYER_ID', 'PLAYER_NAME'], how='left')
    last_merged_df = last_merged_df.fillna(0.0)
    time.sleep(0.5)

# %%
full_merged = pd.merge(left=last_merged_df, right=merged_df, on=['PLAYER_ID', 'PLAYER_NAME'], suffixes=('_LAST', '_CUR'))

# %%
full_merged.columns.tolist()
# Out:
# ['PLAYER_ID',
#  'PLAYER_NAME',
#  'TEAM_ID_LAST',
#  'TEAM_ABBREVIATION_LAST',
#  'GP_LAST',
#  'MIN_LAST',
#  'FGM_LAST',
#  'FGA_LAST',
#  'FG_PCT_LAST',
#  'FG3M_LAST',
#  'FG3A_LAST',
#  'FG3_PCT_LAST',
#  'PTS_LAST',
#  'CATCH_SHOOT_FGM_LAST',
#  'CATCH_SHOOT_FGA_LAST',
#  'PULL_UP_FGM_LAST',
#  'PULL_UP_FGA_LAST',
#  'DRIVE_FGM_LAST',
#  'DRIVE_FGA_LAST',
#  'ELBOW_TOUCH_FGM_LAST',
#  'ELBOW_TOUCH_FGA_LAST',
#  'POST_TOUCH_FGM_LAST',
#  'POST_TOUCH_FGA_LAST',
#  'PAINT_TOUCH_FGM_LAST',
#  'PAINT_TOUCH_FGA_LAST',
#  'TEAM_ID_CUR',
#  'TEAM_ABBREVIATION_CUR',
#  'GP_CUR',
#  'MIN_CUR',
#  'FGM_CUR',
#  'FGA_CUR',
#  'FG_PCT_CUR',
#  'FG3M_CUR',
#  'FG3A_CUR',
#  'FG3_PCT_CUR',
#  'PTS_CUR',
#  'CATCH_SHOOT_FGM_CUR',
#  'CATCH_SHOOT_FGA_CUR',
#  'PULL_UP_FGM_CUR',
#  'PULL_UP_FGA_CUR',
#  'DRIVE_FGM_CUR',
#  'DRIVE_FGA_CUR',
#  'ELBOW_TOUCH_FGM_CUR',
#  'ELBOW_TOUCH_FGA_CUR',
#  'POST_TOUCH_FGM_CUR',
#  'POST_TOUCH_FGA_CUR',
#  'PAINT_TOUCH_FGM_CUR',
#  'PAINT_TOUCH_FGA_CUR']

# %%
row = full_merged.iloc[0]

# %%
def tracking_shot_similarity(row):
    columns = [
        'CATCH_SHOOT_FGA_LAST',
        'PULL_UP_FGA_LAST',
        'DRIVE_FGA_LAST',
        'ELBOW_TOUCH_FGA_LAST',
        'POST_TOUCH_FGA_LAST',
        'PAINT_TOUCH_FGA_LAST',
    ]
    first = row.loc[columns] / row.FGA_LAST
    
    second = row.loc[
        [
            'CATCH_SHOOT_FGA_CUR',
            'PULL_UP_FGA_CUR',
            'DRIVE_FGA_CUR',
            'ELBOW_TOUCH_FGA_CUR',
            'POST_TOUCH_FGA_CUR',
            'PAINT_TOUCH_FGA_CUR'
        ]
    ] / row.FGA_CUR
    
    dot = np.dot(first, second)
    return dot / ((sum([item ** 2 for item in first]) ** 0.5) * (sum([item ** 2 for item in second]) ** 0.5))

# %%
cosines = []
for i in range(len(full_merged)):
    cosines.append(tracking_shot_similarity(full_merged.iloc[i]))

full_merged.loc[:, 'COSINE_SIM'] = cosines

# %%
full_merged.loc[(full_merged.GP_CUR > 5) & (full_merged.MIN_CUR > 15)].sort_values(by='COSINE_SIM')
# Out:
#      PLAYER_ID        PLAYER_NAME  TEAM_ID_LAST TEAM_ABBREVIATION_LAST  \
# 196    1628404          Josh Hart    1610612740                    NOP
# 338     203915  Spencer Dinwiddie    1610612751                    BKN
# 49     1629002      Chimezie Metu    1610612758                    SAC
# 23      201933      Blake Griffin    1610612751                    BKN
# 46        2546    Carmelo Anthony    1610612757                    POR
# ..         ...                ...           ...                    ...
# 128     202066     Garrett Temple    1610612741                    CHI
# 103    1628378   Donovan Mitchell    1610612762                    UTA
# 154    1627826        Ivica Zubac    1610612746                    LAC
# 269    1629011  Mitchell Robinson    1610612752                    NYK
# 52      101108         Chris Paul    1610612756                    PHX
#
#      GP_LAST  MIN_LAST  FGM_LAST  FGA_LAST  FG_PCT_LAST  FG3M_LAST  ...  \
# 196       47      28.7       3.2       7.3        0.439        1.3  ...
# 338        3      21.4       2.0       5.3        0.375        0.7  ...
# 49        36      13.6       2.5       5.0        0.508        0.4  ...
# 23        46      25.8       3.8       8.9        0.423        1.5  ...
# 46        69      24.5       4.7      11.3        0.421        1.9  ...
# ..       ...       ...       ...       ...          ...        ...  ...
# 128       56      27.3       2.8       6.8        0.415        1.2  ...
# 103       53      33.4       9.0      20.6        0.438        3.4  ...
# 154       72      22.3       3.6       5.5        0.652        0.0  ...
# 269       31      27.5       3.7       5.7        0.653        0.0  ...
# 52        70      31.4       6.3      12.6        0.499        1.5  ...
#
#      PULL_UP_FGA_CUR  DRIVE_FGM_CUR  DRIVE_FGA_CUR  ELBOW_TOUCH_FGM_CUR  \
# 196              1.8            1.2            2.7                  0.4
# 338              5.3            2.4            5.1                  0.1
# 49               0.9            0.5            1.4                  0.1
# 23               0.5            0.1            0.5                  0.3
# 46               3.3            0.3            0.6                  0.1
# ..               ...            ...            ...                  ...
# 128              1.1            0.2            0.7                  0.1
# 103              9.2            3.9            7.4                  0.2
# 154              0.1            0.1            0.1                  0.5
# 269              0.0            0.0            0.0                  0.1
# 52               8.0            1.9            3.9                  0.0
#
#      ELBOW_TOUCH_FGA_CUR  POST_TOUCH_FGM_CUR  POST_TOUCH_FGA_CUR  \
# 196                  0.4                 0.1                 0.1
# 338                  0.1                 0.0                 0.0
# 49                   0.3                 0.1                 0.3
# 23                   0.6                 0.1                 0.3
# 46                   0.2                 0.5                 1.2
# ..                   ...                 ...                 ...
# 128                  0.1                 0.0                 0.0
# 103                  0.3                 0.0                 0.0
# 154                  1.0                 0.3                 0.4
# 269                  0.1                 0.0                 0.0
# 52                   0.1                 0.0                 0.1
#
#      PAINT_TOUCH_FGM_CUR  PAINT_TOUCH_FGA_CUR  COSINE_SIM
# 196                  0.5                  0.8    0.689603
# 338                  0.0                  0.0    0.754890
# 49                   1.0                  1.4    0.817668
# 23                   0.8                  1.4    0.821055
# 46                   0.4                  0.7    0.829885
# ..                   ...                  ...         ...
# 128                  0.3                  0.4    0.999462
# 103                  0.3                  0.6    0.999482
# 154                  3.2                  4.6    0.999692
# 269                  2.8                  3.5    0.999768
# 52                   0.0                  0.2    0.999777
#
# [255 rows x 49 columns]
